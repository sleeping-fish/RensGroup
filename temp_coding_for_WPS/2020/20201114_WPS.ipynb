# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('D:/pythonProject/Data/Data4WPS/defocus-lyzosome-633-0.1%-10s-0.8NA-time-200-1800.txt', header=None, delimiter='\t')

# %%
wavenumber = data.iloc[:1639, 1]

# %%
Int = data.iloc[:, 2]
Int
# Out:
# 0        3146.000
# 1        3133.870
# 2        3101.370
# 3        3214.460
# 4        3112.080
#            ...
# 49165    1008.580
# 49166     961.039
# 49167     929.303
# 49168     972.001
# 49169     992.136
# Name: 2, Length: 49170, dtype: float64

# %%
IntArr = Int.to_numpy()

# %%
IntArr = IntArr.reshape(-1, 30)
print(IntArr.shape)
IntDF = pd.DataFrame(IntArr)
# Out:
# (1639, 30)

# %%
IntDF
# Out:
#             0         1         2         3         4         5         6   \
# 0     3146.000  3133.870  3101.370  3214.460  3112.080  3062.130  2994.740
# 1     3117.340  3209.660  3093.210  3194.200  3086.490  3088.920  3169.580
# 2     3146.600  3252.920  3200.490  3174.040  3257.220  3282.700  3201.440
# 3     3327.830  3361.800  3355.550  3372.280  3354.540  3285.110  3304.720
# 4     3544.520  3363.780  3411.890  3408.520  3405.140  3336.020  3555.600
# ...        ...       ...       ...       ...       ...       ...       ...
# 1634   981.810   942.385   937.613   974.406   971.939   962.549   960.085
# 1635   986.245   986.085  1013.500   978.872   990.200   911.939  1049.590
# 1636  1088.980  1059.070  1063.470  1081.590  1044.830  1040.090  1021.640
# 1637  1067.750  1035.700  1026.430  1087.700  1055.670  1053.230  1087.170
# 1638   980.982   908.336   958.014   964.651   955.438  1027.720   975.496
#
# ...

# %%
data2 = data.to_numpy().reshape(-1, 30)

# %%
temp = wavenumber[wavenumber>1450]
temp = temp[temp<1500]
temp
# Out:
# 341    1499.31
# 342    1498.41
# 343    1497.51
# 344    1496.60
# 345    1495.70
# 346    1494.79
# 347    1493.89
# 348    1492.98
# 349    1492.08
# 350    1491.17
# 351    1490.27
# 352    1489.36
# 353    1488.46
# 354    1487.55
# 355    1486.65
# 356    1485.74
# 357    1484.84
# 358    1483.93
# 359    1483.02
# 360    1482.12
# 361    1481.21
# 362    1480.30
# 363    1479.40
# 364    1478.49
# 365    1477.58
# 366    1476.68
# 367    1475.77
# 368    1474.86
# 369    1473.95
# 370    1473.05
# 371    1472.14
# 372    1471.23
# 373    1470.32
# 374    1469.41
# 375    1468.51
# 376    1467.60
# 377    1466.69
# 378    1465.78
# 379    1464.87
# 380    1463.96
# 381    1463.05
# 382    1462.14
# 383    1461.23
# 384    1460.32
# 385    1459.41
# 386    1458.51
# 387    1457.59
# 388    1456.68
# 389    1455.77
# 390    1454.86
# 391    1453.95
# 392    1453.04
# 393    1452.13
# 394    1451.22
# 395    1450.31
# Name: 1, dtype: float64

# %%
plt.figure(figsize=(30,30))
# 385 ~401
for i in range(5,30):
    plt.plot(temp, IntArr[341:396,i]+5e2*i)

# %%
maxSet = []
for i in range(5, 30):
    tempMax = np.argmax(IntArr[385:402, i])
    maxSet.append(tempMax)

# %%
temp = np.array(temp)
waveSet = []
for item in maxSet:
    temp_wave = temp[item]
    waveSet.append(temp_wave)

# %%
waveSet
# Out:
# [1495.7,
#  1495.7,
#  1495.7,
#  1495.7,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79,
#  1494.79]

# %%
plt.figure(figsize=(20,20))
plt.plot(np.arange(5,30)*10, waveSet)
plt.xlabel('time')
plt.ylabel('waveNumber')
# Out:
# Text(0, 0.5, 'waveNumber')
